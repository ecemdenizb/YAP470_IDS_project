# %%
import pandas as pd
from numpy import dtype
import numpy as np
import matplotlib.pyplot as plt;
from sklearn.preprocessing import StandardScaler, LabelEncoder
import seaborn as sns

# %%
dataset = pd.read_csv("/Users/boramert/Desktop/Code/bil570proje/archive/new_df_kucuk_v3.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0   index  Dst Port  Protocol            Timestamp  Flow Duration  \
# 0           0  242184        22         6  14/02/2018 02:38:46         377659
# 1           1  964331        53        17  14/02/2018 12:33:50           1138
# 2           2  203429        22         6  14/02/2018 02:06:35              8
# 3           3  189325        22         6  14/02/2018 02:11:20         379123
# 4           4  261223        22         6  14/02/2018 02:47:56         376212
#
#    Tot Fwd Pkts  Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  ...  \
# 0            22            20             1928             2665  ...
# 1             1             1               45              115  ...
# 2             1             1                0                0  ...
# 3            23            22             1928             2665  ...
# 4            22            20             1912             2665  ...
#
#    Fwd Seg Size Min  Active Mean  Active Std  Active Max  Active Min  \
# 0                32          0.0         0.0           0           0
# 1                 8          0.0         0.0           0           0
# 2                32          0.0         0.0           0           0
# 3                32          0.0         0.0           0           0
# 4                32          0.0         0.0           0           0
#
#    Idle Mean  Idle Std  Idle Max  Idle Min           Label
# 0        0.0       0.0         0         0  SSH-Bruteforce
# 1        0.0       0.0         0         0          Benign
# 2        0.0       0.0         0         0  SSH-Bruteforce
# 3        0.0       0.0         0         0  SSH-Bruteforce
# 4        0.0       0.0         0         0  SSH-Bruteforce
#
# [5 rows x 82 columns]

# %%
dataset['Timestamp'].head()
# Out:
# 0    14/02/2018 02:38:46
# 1    14/02/2018 12:33:50
# 2    14/02/2018 02:06:35
# 3    14/02/2018 02:11:20
# 4    14/02/2018 02:47:56
# Name: Timestamp, dtype: object

# %%
times = pd.to_datetime(dataset['Timestamp'], format = '%d/%m/%Y %H:%M:%S')

# %%
times.head()
# Out:
# 0   2018-02-14 02:38:46
# 1   2018-02-14 12:33:50
# 2   2018-02-14 02:06:35
# 3   2018-02-14 02:11:20
# 4   2018-02-14 02:47:56
# Name: Timestamp, dtype: datetime64[ns]

# %%
times.dt.second.head()
# Out:
# 0    46
# 1    50
# 2    35
# 3    20
# 4    56
# Name: Timestamp, dtype: int64

# %%
dataset['timestamp_year'] = times.dt.year
dataset['timestamp_month'] = times.dt.month
dataset['timestamp_day'] = times.dt.day
dataset['timestamp_hour'] = times.dt.hour
dataset['timestamp_minute'] = times.dt.minute
dataset['timestamp_second'] = times.dt.second

# %%
dataset.drop('Timestamp', axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#    Unnamed: 0   index  Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  \
# 0           0  242184        22         6         377659            22
# 1           1  964331        53        17           1138             1
# 2           2  203429        22         6              8             1
# 3           3  189325        22         6         379123            23
# 4           4  261223        22         6         376212            22
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  ...  \
# 0            20             1928             2665              640  ...
# 1             1               45              115               45  ...
# 2             1                0                0                0  ...
# 3            22             1928             2665              640  ...
# 4            20             1912             2665              640  ...
#
#    Idle Std  Idle Max  Idle Min           Label  timestamp_year  \
# 0       0.0         0         0  SSH-Bruteforce            2018
# 1       0.0         0         0          Benign            2018
# 2       0.0         0         0  SSH-Bruteforce            2018
# 3       0.0         0         0  SSH-Bruteforce            2018
# 4       0.0         0         0  SSH-Bruteforce            2018
#
#    timestamp_month  timestamp_day  timestamp_hour  timestamp_minute  \
# 0                2             14               2                38
# 1                2             14              12                33
# 2                2             14               2                 6
# 3                2             14               2                11
# 4                2             14               2                47
#
#    timestamp_second
# 0                46
# 1                50
# 2                35
# 3                20
# 4                56
#
# [5 rows x 87 columns]

# %%
pd.value_counts(dataset['Label']).plot(kind='bar', figsize=(20, 10))
plt.ylabel('number of instances')
plt.xticks(fontsize=13)
plt.grid()
plt.show()

# %%
dataset.to_csv(r'/Users/boramert/Desktop/Code/bil570proje/archive/dataset_time.csv')
